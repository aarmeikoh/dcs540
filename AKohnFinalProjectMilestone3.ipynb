# %% [markdown]
# # Aaron Kohn
# ## Final Project; Milestone 3

# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
# List of school names, numbers and district
# Extact tables from html
file = str('List of public elementary schools in New York City - Wikipedia.html')
fd = open(file, "r", encoding= 'utf8')
soup = BeautifulSoup(fd)
fd.close()
tables = soup.find_all('table', {'class' : 'wikitable'})
frame = []
for table in tables:
    header = [th.get_text().strip() for th in table.tbody.find_all('tr')[0].find_all('th')]
    rows = table.tbody.find_all('tr')[1:]
    data = [[td.get_text().strip() for td in tr.find_all('td')] for tr in rows]
    df = pd.DataFrame(data, columns= header)
    frame.append(df)
    
# Extract table titles
heads = [h3.get_text().strip() for h3 in soup.find_all('h3')]
heads = ['Manhattan'] + heads[0:13]

# Create data frame with titles as index
ps_df = pd.concat(frame, keys = heads)

# Extract necassary columns and rows
ps_df = ps_df[['SchoolNumber', 'School Name', 'Neighborhood']]
ps_df.drop('Charter schools: citywide[edit]', inplace= True)
ps_df = ps_df.reset_index()
ps_df.drop('level_1', axis= 1, inplace= True)
ps_df.rename(columns={'level_0':'Borough'}, inplace=True)
# ps_df.to_csv('NYC.csv')
# ps_df = pd.read_csv('NYC.csv')
ps_df
# Out:
#                                            Borough SchoolNumber  \
# 0                                        Manhattan         PS 1
# 1                                        Manhattan        PS 11
# 2                                        Manhattan        PS 15
# 3                                        Manhattan        PS 18
# 4                                        Manhattan        PS 19
# ..                                             ...          ...
# 772  Special Education District 75: citywide[edit]      PS 231K
# 773  Special Education District 75: citywide[edit]       PS 327
# 774  Special Education District 75: citywide[edit]     PS 373 R
# 775  Special Education District 75: citywide[edit]     PS 352 X
# 776  Special Education District 75: citywide[edit]       PS 371
#
#                                  School Name  Neighborhood
# 0                            Alfred F. Smith   Two Bridges
# 1                          William T. Harris       Chelsea
# 2                           Roberto Clemente  East Village
# 3                               Park Terrace        Inwood
# 4                                 Asher Levy  East Village
# ..                                       ...           ...
# 772
# 773                    The Children’s School
# 774
# 775  The Vida Bogart School for All Children
# 776                       Lillian L. Rashkis
#
# [777 rows x 4 columns]

# %%
# Switch column School Name to lower case for matching
ps_df['School Name'] = ps_df['School Name'].apply(lambda x : x.lower())
ps_df.head()
# Out:
#      Borough SchoolNumber        School Name  Neighborhood
# 0  Manhattan         PS 1    alfred f. smith   Two Bridges
# 1  Manhattan        PS 11  william t. harris       Chelsea
# 2  Manhattan        PS 15   roberto clemente  East Village
# 3  Manhattan        PS 18       park terrace        Inwood
# 4  Manhattan        PS 19         asher levy  East Village

# %%
# Import school data information from multiple pages(1 page per file)
frame2 = [] # Create list to store pages
for i in range(1, 138): # Iterate through files named in order
    file = str('state ' + str(i) +'.html') # create file names
    fd = open(file, "r", encoding= 'utf8')
    soup = BeautifulSoup(fd)
    fd.close()
    table = soup.find('table', {'class' : 'ls'})
    header = [td.get_text().strip() for td in table.tbody.find_all('tr')[0].find_all('td')]
    rows = table.tbody.find_all('tr')[1:]
    data = [[td.get_text().strip() for td in tr.find_all('td')] for tr in rows]
    html_df = pd.DataFrame(data, columns= header)
    frame2.append(html_df)

# %%
full_html = pd.concat(frame2, ignore_index=True) # merge all pages to one frame
# full_html.to_csv('NYS.csv') # Save to csv
# full_html = pd.read_csv('NYS.csv') # Read from saved csv
full_html.head()
# Out:
#   Institution ID                                         Legal Name  \
# 0  -800000090834  HELLENIC CLASSICAL CHARTER SCHOOL - STATEN ISLAND
# 1  -800000059005                           SMILES AROUND US ACADEMY
# 2  -800000091532  EDEN II SCHOOL FOR AUTISTIC CHILDREN, INC. LIT...
# 3  -800000091977  EDEN II SCHOOL FOR AUTISTIC CHILDREN - MANOR ROAD
# 4  -800000041775                              STATEN ISLAND ACADEMY
#
#                            Popular Name      SED Code INST Type Code  \
# 0  HELLENIC CLASSICAL CS -STATEN ISLAND  353100861175             17
# 1              SMILES AROUND US ACADEMY  353100995152             14
# 2             EDEN II - LITTLE MIRACLES  353100996532             14
# 3                  EDEN II - MANOR ROAD  353100996570             14
# 4                 STATEN ISLAND ACADEMY  353100997022             14
#
#   INST Type Description INST Sub Type Code INST Sub Type Description  \
# 0        PUBLIC SCHOOLS                 11            CHARTER SCHOOL
# 1    NON-PUBLIC SCHOOLS                 21               INDEPENDENT
# 2    NON-PUBLIC SCHOOLS                 21               INDEPENDENT
# 3    NON-PUBLIC SCHOOLS                 21               INDEPENDENT
# 4    NON-PUBLIC SCHOOLS                 21               INDEPENDENT
#
#   County Code County Description  ... Grade 5 Grade 6  \
# 0          35           RICHMOND  ...
# 1          35           RICHMOND  ...       Y       Y
# 2          35           RICHMOND  ...
# 3          35           RICHMOND  ...
# 4          35           RICHMOND  ...       Y       Y
#
#   Grade Ungraded Elementary Grade 7 Grade 8 Grade 9 Grade 10 Grade 11  \
# 0
# 1                                 Y
# 2
# 3
# 4                                 Y       Y       Y        Y        Y
#
#   Grade 12 Grade Ungraded Secondary
# 0
# 1
# 2
# 3
# 4        Y
#
# [5 rows x 46 columns]

# %%
# Select desired rows
public_df = full_html[full_html['INST Sub Type Description'] == 'PUBLIC SCHOOL CITY'] # Select only City Public Schools
fiveborough = ['RICHMOND', 'QUEENS', 'KINGS', 'BRONX', 'NEW YORK']
public_df = public_df[(public_df["County Description"].isin(fiveborough))] # Select only NYC schools

public_df
# Out:
#      Institution ID                                     Legal Name  \
# 60    -800000088504    PORT RICHMOND SCHOOL FOR VISIONARY LEARNING
# 61    -800000042011                        PS 69 DANIEL D TOMPKINS
# 62    -800000042012                             IS 72 ROCCO LAURIE
# 63    -800000069167         PS 74 FUTURE LEADERS ELEMENTARY SCHOOL
# 64    -800000042013                            IS 75 FRANK D PAULO
# ...             ...                                            ...
# 2735  -800000046867                        PS 169 ROBERT F KENNEDY
# 2736  -800000046870                                         PS 226
# 2737  -800000046871                               HOSPITAL SCHOOLS
# 2738  -800000046872  PS 721 MANHATTAN OCCUPATIONAL TRAINING CENTER
# 2739  -800000046874        MANHATTAN SCHOOL FOR CAREER DEVELOPMENT
#
#                              Popular Name      SED Code INST Type Code  \
# 60     PORT RICHMOND SCHOOL FOR VISIONARY  353100010068             17
# 61                PS 69 DANIEL D TOMPKINS  353100010069             17
# 62                     IS 72 ROCCO LAURIE  353100010072             17
# 63        PS 74 FUTURE LEADERS ELEMENTARY  353100010074             17
# 64                    IS 75 FRANK D PAULO  353100010075             17
# ...                                   ...           ...            ...
# 2735              PS 169 ROBERT F KENNEDY  307500011169             17
# 2736                               PS 226  307500011226             17
# 2737                     HOSPITAL SCHOOLS  307500011401             17
# 2738      PS 721 MANHATTAN OCC TRNING CTR  307500011721             17
# 2739  MANHATTAN SCHOOL FOR CAREER DVLPMNT  307500011751             17
#
#      INST Type Description INST Sub Type Code INST Sub Type Description  \
# 60          PUBLIC SCHOOLS                  1        PUBLIC SCHOOL CITY
# 61          PUBLIC SCHOOLS                  1        PUBLIC SCHOOL CITY
# 62          PUBLIC SCHOOLS                  1        PUBLIC SCHOOL CITY
# 63          PUBLIC SCHOOLS                  1        PUBLIC SCHOOL CITY
# 64          PUBLIC SCHOOLS                  1        PUBLIC SCHOOL CITY
# ...                    ...                ...                       ...
# 2735        PUBLIC SCHOOLS                  1        PUBLIC SCHOOL CITY
# 2736        PUBLIC SCHOOLS                  1        PUBLIC SCHOOL CITY
# 2737        PUBLIC SCHOOLS                  1        PUBLIC SCHOOL CITY
# 2738        PUBLIC SCHOOLS                  1        PUBLIC SCHOOL CITY
# 2739        PUBLIC SCHOOLS                  1        PUBLIC SCHOOL CITY
#
#      County Code County Description  ... Grade 5 Grade 6  \
# 60            35           RICHMOND  ...
# 61            35           RICHMOND  ...       Y
# 62            35           RICHMOND  ...               Y
# 63            35           RICHMOND  ...       Y
# 64            35           RICHMOND  ...               Y
# ...          ...                ...  ...     ...     ...
# 2735          31           NEW YORK  ...       Y       Y
# 2736          31           NEW YORK  ...               Y
# 2737          32              BRONX  ...
# 2738          31           NEW YORK  ...
# 2739          31           NEW YORK  ...
#
#      Grade Ungraded Elementary Grade 7 Grade 8 Grade 9 Grade 10 Grade 11  \
# 60
# 61
# 62                                   Y       Y
# 63
# 64                           Y       Y       Y
# ...                        ...     ...     ...     ...      ...      ...
# 2735                         Y       Y       Y       Y                 Y
# 2736                         Y       Y               Y        Y
# 2737                         Y
# 2738                         Y                       Y        Y        Y
# 2739                         Y       Y       Y       Y        Y        Y
#
#      Grade 12 Grade Ungraded Secondary
# 60
# 61
# 62                                   Y
# 63
# 64                                   Y
# ...       ...                      ...
# 2735        Y                        Y
# 2736        Y                        Y
# 2737
# 2738        Y                        Y
# 2739        Y                        Y
#
# [1584 rows x 46 columns]

# %%
# Switch column Legal Name to lower case for matching
public_df['Legal Name'] = public_df['Legal Name'].apply(lambda x : x.lower())
public_df.head()
# Out:
#    Institution ID                                   Legal Name  \
# 60  -800000088504  port richmond school for visionary learning
# 61  -800000042011                      ps 69 daniel d tompkins
# 62  -800000042012                           is 72 rocco laurie
# 63  -800000069167       ps 74 future leaders elementary school
# 64  -800000042013                          is 75 frank d paulo
#
#                           Popular Name      SED Code INST Type Code  \
# 60  PORT RICHMOND SCHOOL FOR VISIONARY  353100010068             17
# 61             PS 69 DANIEL D TOMPKINS  353100010069             17
# 62                  IS 72 ROCCO LAURIE  353100010072             17
# 63     PS 74 FUTURE LEADERS ELEMENTARY  353100010074             17
# 64                 IS 75 FRANK D PAULO  353100010075             17
#
#    INST Type Description INST Sub Type Code INST Sub Type Description  \
# 60        PUBLIC SCHOOLS                  1        PUBLIC SCHOOL CITY
# 61        PUBLIC SCHOOLS                  1        PUBLIC SCHOOL CITY
# 62        PUBLIC SCHOOLS                  1        PUBLIC SCHOOL CITY
# 63        PUBLIC SCHOOLS                  1        PUBLIC SCHOOL CITY
# 64        PUBLIC SCHOOLS                  1        PUBLIC SCHOOL CITY
#
#    County Code County Description  ... Grade 5 Grade 6  \
# 60          35           RICHMOND  ...
# 61          35           RICHMOND  ...       Y
# 62          35           RICHMOND  ...               Y
# 63          35           RICHMOND  ...       Y
# 64          35           RICHMOND  ...               Y
#
#    Grade Ungraded Elementary Grade 7 Grade 8 Grade 9 Grade 10 Grade 11  \
# 60
# 61
# 62                                 Y       Y
# 63
# 64                         Y       Y       Y
#
#    Grade 12 Grade Ungraded Secondary
# 60
# 61
# 62                                 Y
# 63
# 64                                 Y
#
# [5 rows x 46 columns]

# %%
# Add column School name_num by combining SchoolNumber and School Name for matching
ps_df['School name_num'] = ps_df['SchoolNumber']+' ' + ps_df['School Name']
ps_df['School name_num'] = ps_df['School name_num'].apply(lambda x : x.lower()) # Convert to lowercase
ps_df
# Out:
#                                            Borough SchoolNumber  \
# 0                                        Manhattan         PS 1
# 1                                        Manhattan        PS 11
# 2                                        Manhattan        PS 15
# 3                                        Manhattan        PS 18
# 4                                        Manhattan        PS 19
# ..                                             ...          ...
# 772  Special Education District 75: citywide[edit]      PS 231K
# 773  Special Education District 75: citywide[edit]       PS 327
# 774  Special Education District 75: citywide[edit]     PS 373 R
# 775  Special Education District 75: citywide[edit]     PS 352 X
# 776  Special Education District 75: citywide[edit]       PS 371
#
#                                  School Name  Neighborhood  \
# 0                            alfred f. smith   Two Bridges
# 1                          william t. harris       Chelsea
# 2                           roberto clemente  East Village
# 3                               park terrace        Inwood
# 4                                 asher levy  East Village
# ..                                       ...           ...
# 772
# 773                    the children’s school
# 774
# 775  the vida bogart school for all children
# 776                       lillian l. rashkis
#
#                                       School name_num
# 0                                ps 1 alfred f. smith
# 1                             ps 11 william t. harris
# 2                              ps 15 roberto clemente
# 3                                  ps 18 park terrace
# 4                                    ps 19 asher levy
# ..                                                ...
# 772                                          ps 231k
# 773                      ps 327 the children’s school
# 774                                         ps 373 r
# 775  ps 352 x the vida bogart school for all children
# 776                         ps 371 lillian l. rashkis
#
# [777 rows x 5 columns]

# %%
# making separate column for school number
# new = public_df["Legal Name"].str.split(" ",  expand = True) 
# public_df["School_Num"]= new[1]
# public_df.head(3)

# %%
from fuzzywuzzy import process, fuzz
import logging
logging.getLogger().setLevel(logging.ERROR)

# %%
# Use fuzzywuzzy token_sort_ratio to find matching school names retirns columns with name found and similarity ratio
actual_name = []
similarity = []
for i in ps_df['School name_num']:
        ratio = process.extract( i, public_df['Legal Name'], limit=1, scorer= fuzz.token_sort_ratio)
        actual_name.append(ratio[0][0])
        similarity.append(ratio[0][1])
ps_df['actual_name'] = pd.Series(actual_name)
ps_df['similarity'] = pd.Series(similarity)
ps_df
# Out:
#                                            Borough SchoolNumber  \
# 0                                        Manhattan         PS 1
# 1                                        Manhattan        PS 11
# 2                                        Manhattan        PS 15
# 3                                        Manhattan        PS 18
# 4                                        Manhattan        PS 19
# ..                                             ...          ...
# 772  Special Education District 75: citywide[edit]      PS 231K
# 773  Special Education District 75: citywide[edit]       PS 327
# 774  Special Education District 75: citywide[edit]     PS 373 R
# 775  Special Education District 75: citywide[edit]     PS 352 X
# 776  Special Education District 75: citywide[edit]       PS 371
#
#                                  School Name  Neighborhood  \
# 0                            alfred f. smith   Two Bridges
# 1                          william t. harris       Chelsea
# 2                           roberto clemente  East Village
# 3                               park terrace        Inwood
# 4                                 asher levy  East Village
# ..                                       ...           ...
# 772
# 773                    the children’s school
# 774
# 775  the vida bogart school for all children
# 776                       lillian l. rashkis
#
#                                       School name_num  \
# 0                                ps 1 alfred f. smith
# 1                             ps 11 william t. harris
# 2                              ps 15 roberto clemente
# 3                                  ps 18 park terrace
# 4                                    ps 19 asher levy
# ..                                                ...
# 772                                          ps 231k
# 773                      ps 327 the children’s school
# 774                                         ps 373 r
# 775  ps 352 x the vida bogart school for all children
# 776                         ps 371 lillian l. rashkis
#
#                                    actual_name  similarity
# 0                          ps 1 alfred e smith          95
# 1                       ps 11 william t harris         100
# 2                       ps 15 roberto clemente         100
# 3                           ps 18 park terrace         100
# 4                             ps 19 asher levy         100
# ..                                         ...         ...
# 772                                     ps 231          92
# 773             ps 372 children's school (the)          96
# 774                                     ps 373          86
# 775  vida bogart school for all children (the)          90
# 776                   ps 371 lillian l rashkis         100
#
# [777 rows x 7 columns]

# %%
# merge data frames on fuzzy matched names
merged_df = ps_df.merge(public_df, left_on= 'actual_name', right_on= 'Legal Name')

# %%
# Drop unwanted and duplicated columns
merged_df.drop(['Institution ID', 'Popular Name', 'actual_name', 'SED Code', 'INST Type Code','INST Sub Type Code', 'Physical Address Line1', 'Physical Address Line2',
               'Physical State Code', 'Physical Zipcd5', 'Mailing Address Line1', 'Mailing Address Line2', 'Mailing City', 'Mailing State Code',
               'Mailing Zipcd5', 'CEO email', 'CEO Phone', 'CEO Phone Extension', 'Grade Organization Code'], axis = 1, inplace= True)

# %%
# Drop duplicate schools (based on name and county code)
merged_df = merged_df.drop_duplicates(subset= ['SchoolNumber', 'County Code'])

merged_df
# Out:
#                                            Borough SchoolNumber  \
# 0                                        Manhattan         PS 1
# 1                                        Manhattan        PS 11
# 3                                        Manhattan        PS 15
# 5                                        Manhattan        PS 18
# 7                                        Manhattan        PS 19
# ..                                             ...          ...
# 777  Special Education District 75: citywide[edit]     PS 224 Q
# 778  Special Education District 75: citywide[edit]      PS 231K
# 779  Special Education District 75: citywide[edit]     PS 373 R
# 780  Special Education District 75: citywide[edit]     PS 352 X
# 781  Special Education District 75: citywide[edit]       PS 371
#
#                                  School Name  Neighborhood  \
# 0                            alfred f. smith   Two Bridges
# 1                          william t. harris       Chelsea
# 3                           roberto clemente  East Village
# 5                               park terrace        Inwood
# 7                                 asher levy  East Village
# ..                                       ...           ...
# 777
# 778
# 779
# 780  the vida bogart school for all children
# 781                       lillian l. rashkis
#
#                                       School name_num  similarity  \
# 0                                ps 1 alfred f. smith          95
# 1                             ps 11 william t. harris         100
# 3                              ps 15 roberto clemente         100
# 5                                  ps 18 park terrace         100
# 7                                    ps 19 asher levy         100
# ..                                                ...         ...
# 777                                         ps 224 q           86
# 778                                          ps 231k           92
# 779                                         ps 373 r           86
# 780  ps 352 x the vida bogart school for all children          90
# 781                         ps 371 lillian l. rashkis         100
#
#                                     Legal Name INST Type Description  \
# 0                          ps 1 alfred e smith        PUBLIC SCHOOLS
# 1                       ps 11 william t harris        PUBLIC SCHOOLS
# 3                       ps 15 roberto clemente        PUBLIC SCHOOLS
# 5                           ps 18 park terrace        PUBLIC SCHOOLS
# 7                             ps 19 asher levy        PUBLIC SCHOOLS
# ..                                         ...                   ...
# 777                                     ps 224        PUBLIC SCHOOLS
# 778                                     ps 231        PUBLIC SCHOOLS
# 779                                     ps 373        PUBLIC SCHOOLS
# 780  vida bogart school for all children (the)        PUBLIC SCHOOLS
# 781                   ps 371 lillian l rashkis        PUBLIC SCHOOLS
#
#     INST Sub Type Description County Code  ... Grade 5 Grade 6  \
# 0          PUBLIC SCHOOL CITY          31  ...       Y
# 1          PUBLIC SCHOOL CITY          31  ...       Y
# 3          PUBLIC SCHOOL CITY          31  ...       Y
# 5          PUBLIC SCHOOL CITY          31  ...       Y       Y
# 7          PUBLIC SCHOOL CITY          31  ...       Y
# ..                        ...         ...  ...     ...     ...
# 777        PUBLIC SCHOOL CITY          34  ...       Y       Y
# 778        PUBLIC SCHOOL CITY          33  ...       Y       Y
# 779        PUBLIC SCHOOL CITY          35  ...       Y
# 780        PUBLIC SCHOOL CITY          32  ...       Y       Y
# 781        PUBLIC SCHOOL CITY          33  ...
#
#     Grade Ungraded Elementary Grade 7 Grade 8 Grade 9 Grade 10 Grade 11  \
# 0
# 1                           Y
# 3                           Y
# 5                                   Y       Y
# 7
# ..                        ...     ...     ...     ...      ...      ...
# 777                         Y       Y       Y
# 778                         Y       Y       Y
# 779                         Y               Y
# 780                         Y       Y       Y
# 781                                                 Y        Y        Y
#
#     Grade 12 Grade Ungraded Secondary
# 0
# 1
# 3
# 5
# 7
# ..       ...                      ...
# 777                                 Y
# 778                                 Y
# 779                                 Y
# 780
# 781        Y                        Y
#
# [678 rows x 34 columns]

# %%
# drop rows missing school number
merged_df['SchoolNumber'].replace('', np.nan, inplace= True ) # Replace empty string with nan
merged_df = merged_df[merged_df['SchoolNumber'].notna()]
merged_df
# Out:
#                                            Borough SchoolNumber  \
# 0                                        Manhattan         PS 1
# 1                                        Manhattan        PS 11
# 3                                        Manhattan        PS 15
# 5                                        Manhattan        PS 18
# 7                                        Manhattan        PS 19
# ..                                             ...          ...
# 777  Special Education District 75: citywide[edit]     PS 224 Q
# 778  Special Education District 75: citywide[edit]      PS 231K
# 779  Special Education District 75: citywide[edit]     PS 373 R
# 780  Special Education District 75: citywide[edit]     PS 352 X
# 781  Special Education District 75: citywide[edit]       PS 371
#
#                                  School Name  Neighborhood  \
# 0                            alfred f. smith   Two Bridges
# 1                          william t. harris       Chelsea
# 3                           roberto clemente  East Village
# 5                               park terrace        Inwood
# 7                                 asher levy  East Village
# ..                                       ...           ...
# 777
# 778
# 779
# 780  the vida bogart school for all children
# 781                       lillian l. rashkis
#
#                                       School name_num  similarity  \
# 0                                ps 1 alfred f. smith          95
# 1                             ps 11 william t. harris         100
# 3                              ps 15 roberto clemente         100
# 5                                  ps 18 park terrace         100
# 7                                    ps 19 asher levy         100
# ..                                                ...         ...
# 777                                         ps 224 q           86
# 778                                          ps 231k           92
# 779                                         ps 373 r           86
# 780  ps 352 x the vida bogart school for all children          90
# 781                         ps 371 lillian l. rashkis         100
#
#                                     Legal Name INST Type Description  \
# 0                          ps 1 alfred e smith        PUBLIC SCHOOLS
# 1                       ps 11 william t harris        PUBLIC SCHOOLS
# 3                       ps 15 roberto clemente        PUBLIC SCHOOLS
# 5                           ps 18 park terrace        PUBLIC SCHOOLS
# 7                             ps 19 asher levy        PUBLIC SCHOOLS
# ..                                         ...                   ...
# 777                                     ps 224        PUBLIC SCHOOLS
# 778                                     ps 231        PUBLIC SCHOOLS
# 779                                     ps 373        PUBLIC SCHOOLS
# 780  vida bogart school for all children (the)        PUBLIC SCHOOLS
# 781                   ps 371 lillian l rashkis        PUBLIC SCHOOLS
#
#     INST Sub Type Description County Code  ... Grade 5 Grade 6  \
# 0          PUBLIC SCHOOL CITY          31  ...       Y
# 1          PUBLIC SCHOOL CITY          31  ...       Y
# 3          PUBLIC SCHOOL CITY          31  ...       Y
# 5          PUBLIC SCHOOL CITY          31  ...       Y       Y
# 7          PUBLIC SCHOOL CITY          31  ...       Y
# ..                        ...         ...  ...     ...     ...
# 777        PUBLIC SCHOOL CITY          34  ...       Y       Y
# 778        PUBLIC SCHOOL CITY          33  ...       Y       Y
# 779        PUBLIC SCHOOL CITY          35  ...       Y
# 780        PUBLIC SCHOOL CITY          32  ...       Y       Y
# 781        PUBLIC SCHOOL CITY          33  ...
#
#     Grade Ungraded Elementary Grade 7 Grade 8 Grade 9 Grade 10 Grade 11  \
# 0
# 1                           Y
# 3                           Y
# 5                                   Y       Y
# 7
# ..                        ...     ...     ...     ...      ...      ...
# 777                         Y       Y       Y
# 778                         Y       Y       Y
# 779                         Y               Y
# 780                         Y       Y       Y
# 781                                                 Y        Y        Y
#
#     Grade 12 Grade Ungraded Secondary
# 0
# 1
# 3
# 5
# 7
# ..       ...                      ...
# 777                                 Y
# 778                                 Y
# 779                                 Y
# 780
# 781        Y                        Y
#
# [674 rows x 34 columns]

# %%
# Fill true/false data with Y/N may require replacement with boolean values
merged_df.iloc[:, -18:-1] = merged_df.iloc[:, -18:-1].replace('', 'N') # Replace empty string with 'N'
merged_df
# Out:
# C:\Users\aarme\anaconda3.2\lib\site-packages\pandas\core\indexing.py:1754: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, val, pi)
#                                            Borough SchoolNumber  \
# 0                                        Manhattan         PS 1
# 1                                        Manhattan        PS 11
# 3                                        Manhattan        PS 15
# 5                                        Manhattan        PS 18
# 7                                        Manhattan        PS 19
# ..                                             ...          ...
# 777  Special Education District 75: citywide[edit]     PS 224 Q
# 778  Special Education District 75: citywide[edit]      PS 231K
# 779  Special Education District 75: citywide[edit]     PS 373 R
# 780  Special Education District 75: citywide[edit]     PS 352 X
# 781  Special Education District 75: citywide[edit]       PS 371
#
#                                  School Name  Neighborhood  \
# 0                            alfred f. smith   Two Bridges
# 1                          william t. harris       Chelsea
# 3                           roberto clemente  East Village
# 5                               park terrace        Inwood
# 7                                 asher levy  East Village
# ..                                       ...           ...
# 777
# 778
# 779
# 780  the vida bogart school for all children
# 781                       lillian l. rashkis
#
#                                       School name_num  similarity  \
# 0                                ps 1 alfred f. smith          95
# 1                             ps 11 william t. harris         100
# 3                              ps 15 roberto clemente         100
# 5                                  ps 18 park terrace         100
# 7                                    ps 19 asher levy         100
# ..                                                ...         ...
# 777                                         ps 224 q           86
# 778                                          ps 231k           92
# 779                                         ps 373 r           86
# 780  ps 352 x the vida bogart school for all children          90
# 781                         ps 371 lillian l. rashkis         100
#
#                                     Legal Name INST Type Description  \
# 0                          ps 1 alfred e smith        PUBLIC SCHOOLS
# 1                       ps 11 william t harris        PUBLIC SCHOOLS
# 3                       ps 15 roberto clemente        PUBLIC SCHOOLS
# 5                           ps 18 park terrace        PUBLIC SCHOOLS
# 7                             ps 19 asher levy        PUBLIC SCHOOLS
# ..                                         ...                   ...
# 777                                     ps 224        PUBLIC SCHOOLS
# 778                                     ps 231        PUBLIC SCHOOLS
# 779                                     ps 373        PUBLIC SCHOOLS
# 780  vida bogart school for all children (the)        PUBLIC SCHOOLS
# 781                   ps 371 lillian l rashkis        PUBLIC SCHOOLS
#
#     INST Sub Type Description County Code  ... Grade 5 Grade 6  \
# 0          PUBLIC SCHOOL CITY          31  ...       Y       N
# 1          PUBLIC SCHOOL CITY          31  ...       Y       N
# 3          PUBLIC SCHOOL CITY          31  ...       Y       N
# 5          PUBLIC SCHOOL CITY          31  ...       Y       Y
# 7          PUBLIC SCHOOL CITY          31  ...       Y       N
# ..                        ...         ...  ...     ...     ...
# 777        PUBLIC SCHOOL CITY          34  ...       Y       Y
# 778        PUBLIC SCHOOL CITY          33  ...       Y       Y
# 779        PUBLIC SCHOOL CITY          35  ...       Y       N
# 780        PUBLIC SCHOOL CITY          32  ...       Y       Y
# 781        PUBLIC SCHOOL CITY          33  ...       N       N
#
#     Grade Ungraded Elementary Grade 7 Grade 8 Grade 9 Grade 10 Grade 11  \
# 0                           N       N       N       N        N        N
# 1                           Y       N       N       N        N        N
# 3                           Y       N       N       N        N        N
# 5                           N       Y       Y       N        N        N
# 7                           N       N       N       N        N        N
# ..                        ...     ...     ...     ...      ...      ...
# 777                         Y       Y       Y       N        N        N
# 778                         Y       Y       Y       N        N        N
# 779                         Y       N       Y       N        N        N
# 780                         Y       Y       Y       N        N        N
# 781                         N       N       N       Y        Y        Y
#
#     Grade 12 Grade Ungraded Secondary
# 0          N
# 1          N
# 3          N
# 5          N
# 7          N
# ..       ...                      ...
# 777        N                        Y
# 778        N                        Y
# 779        N                        Y
# 780        N
# 781        Y                        Y
#
# [674 rows x 34 columns]

# %%
# Replace empty strings with nan for remaining columns
merged_df.replace('', np.nan, inplace= True)
merged_df
# Out:
# C:\Users\aarme\anaconda3.2\lib\site-packages\pandas\core\frame.py:4524: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(
#                                            Borough SchoolNumber  \
# 0                                        Manhattan         PS 1
# 1                                        Manhattan        PS 11
# 3                                        Manhattan        PS 15
# 5                                        Manhattan        PS 18
# 7                                        Manhattan        PS 19
# ..                                             ...          ...
# 777  Special Education District 75: citywide[edit]     PS 224 Q
# 778  Special Education District 75: citywide[edit]      PS 231K
# 779  Special Education District 75: citywide[edit]     PS 373 R
# 780  Special Education District 75: citywide[edit]     PS 352 X
# 781  Special Education District 75: citywide[edit]       PS 371
#
#                                  School Name  Neighborhood  \
# 0                            alfred f. smith   Two Bridges
# 1                          william t. harris       Chelsea
# 3                           roberto clemente  East Village
# 5                               park terrace        Inwood
# 7                                 asher levy  East Village
# ..                                       ...           ...
# 777                                      NaN           NaN
# 778                                      NaN           NaN
# 779                                      NaN           NaN
# 780  the vida bogart school for all children           NaN
# 781                       lillian l. rashkis           NaN
#
#                                       School name_num  similarity  \
# 0                                ps 1 alfred f. smith          95
# 1                             ps 11 william t. harris         100
# 3                              ps 15 roberto clemente         100
# 5                                  ps 18 park terrace         100
# 7                                    ps 19 asher levy         100
# ..                                                ...         ...
# 777                                         ps 224 q           86
# 778                                          ps 231k           92
# 779                                         ps 373 r           86
# 780  ps 352 x the vida bogart school for all children          90
# 781                         ps 371 lillian l. rashkis         100
#
#                                     Legal Name INST Type Description  \
# 0                          ps 1 alfred e smith        PUBLIC SCHOOLS
# 1                       ps 11 william t harris        PUBLIC SCHOOLS
# 3                       ps 15 roberto clemente        PUBLIC SCHOOLS
# 5                           ps 18 park terrace        PUBLIC SCHOOLS
# 7                             ps 19 asher levy        PUBLIC SCHOOLS
# ..                                         ...                   ...
# 777                                     ps 224        PUBLIC SCHOOLS
# 778                                     ps 231        PUBLIC SCHOOLS
# 779                                     ps 373        PUBLIC SCHOOLS
# 780  vida bogart school for all children (the)        PUBLIC SCHOOLS
# 781                   ps 371 lillian l rashkis        PUBLIC SCHOOLS
#
#     INST Sub Type Description County Code  ... Grade 5 Grade 6  \
# 0          PUBLIC SCHOOL CITY          31  ...       Y       N
# 1          PUBLIC SCHOOL CITY          31  ...       Y       N
# 3          PUBLIC SCHOOL CITY          31  ...       Y       N
# 5          PUBLIC SCHOOL CITY          31  ...       Y       Y
# 7          PUBLIC SCHOOL CITY          31  ...       Y       N
# ..                        ...         ...  ...     ...     ...
# 777        PUBLIC SCHOOL CITY          34  ...       Y       Y
# 778        PUBLIC SCHOOL CITY          33  ...       Y       Y
# 779        PUBLIC SCHOOL CITY          35  ...       Y       N
# 780        PUBLIC SCHOOL CITY          32  ...       Y       Y
# 781        PUBLIC SCHOOL CITY          33  ...       N       N
#
#     Grade Ungraded Elementary Grade 7 Grade 8 Grade 9 Grade 10 Grade 11  \
# 0                           N       N       N       N        N        N
# 1                           Y       N       N       N        N        N
# 3                           Y       N       N       N        N        N
# 5                           N       Y       Y       N        N        N
# 7                           N       N       N       N        N        N
# ..                        ...     ...     ...     ...      ...      ...
# 777                         Y       Y       Y       N        N        N
# 778                         Y       Y       Y       N        N        N
# 779                         Y       N       Y       N        N        N
# 780                         Y       Y       Y       N        N        N
# 781                         N       N       N       Y        Y        Y
#
#     Grade 12 Grade Ungraded Secondary
# 0          N                      NaN
# 1          N                      NaN
# 3          N                      NaN
# 5          N                      NaN
# 7          N                      NaN
# ..       ...                      ...
# 777        N                        Y
# 778        N                        Y
# 779        N                        Y
# 780        N                      NaN
# 781        Y                        Y
#
# [674 rows x 34 columns]

# %%
merged_df.to_csv('merged_df.csv')
